# %%
import pandas as pd
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Compare structure of raw data and transformed data

# %%
# read untransformed data
diabetes_cohort = pd.read_csv('/content/drive/MyDrive/Data/Output/diabetes_cohort.csv')
diabetes_cohort
# Out:
#              BENE_ID   CCSR_CATEGORY_DESCRIPTION_updated    YR  \
# 0    -10000010288010                             Obesity  2015
# 1    -10000010288010  Socioeconomic or lifestyle factors  2015
# 2    -10000010288010                         Prediabetes  2015
# 3    -10000010287943            Heart disease or failure  2015
# 4    -10000010287943                             Obesity  2015
# ...              ...                                 ...   ...
# 8072 -10000010254676                        Hypertension  2017
# 8073 -10000010254671                             Obesity  2015
# 8074 -10000010254671  Socioeconomic or lifestyle factors  2015
# 8075 -10000010254671                         Prediabetes  2015
# 8076 -10000010254671            Heart disease or failure  2015
#
#       TIME_SINCE_ENROLLMT
# 0                       5
# 1                      10
# 2                      11
# 3                       2
# 4                       3
# ...                   ...
# 8072                   26
# 8073                    2
# 8074                    7
# 8075                    8
# 8076                    9
#
# [8077 rows x 4 columns]

# %%
# read transformed data
diabetes_cohort_transformed = pd.read_csv('/content/drive/MyDrive/Data/Output/diab_cohort.csv')
diabetes_cohort_transformed
# Out:
#              BENE_ID  TIME  STATE  Obesity  \
# 0    -10000010288010     0      0        0
# 1    -10000010288010     5      0        1
# 2    -10000010288010    10      0        1
# 3    -10000010288010    11      1        1
# 4    -10000010287943     0      0        0
# ...              ...   ...    ...      ...
# 9013 -10000010254671     0      0        0
# 9014 -10000010254671     2      0        1
# 9015 -10000010254671     7      0        1
# 9016 -10000010254671     8      1        1
# 9017 -10000010254671     9      1        1
#
#       Socioeconomic.or.lifestyle.factors  Heart.disease.or.failure  \
# 0                                      0                         0
# 1                                      0                         0
# 2                                      1                         0
# 3                                      1                         0
# 4                                      0                         0
# ...                                  ...                       ...
# 9013                                   0                         0
# 9014                                   0                         0
# 9015                                   1                         0
# 9016                                   1                         0
# 9017                                   1                         1
#
#       Hypertension  Sleep.wake.disorders  Depressive.or.anxiety.disorders  \
# 0                0                     0                                0
# 1                0                     0                                0
# 2                0                     0                                0
# 3                0                     0                                0
# 4                0                     0                                0
# ...            ...                   ...                              ...
# 9013             0                     0                                0
# 9014             0                     0                                0
# 9015             0                     0                                0
# 9016             0                     0                                0
# 9017             0                     0                                0
#
#       Alcohol.related.disorders  SEX_IDENT_CD  BENE_RACE_CD  AGE_CALC  \
# 0                             0             1             5        54
# 1                             0             1             5        54
# 2                             0             1             5        54
# 3                             0             1             5        54
# 4                             0             2             1        75
# ...                         ...           ...           ...       ...
# 9013                          0             2             2        74
# 9014                          0             2             2        74
# 9015                          0             2             2        74
# 9016                          0             2             2        74
# 9017                          0             2             2        74
#
#              AGE_GRP
# 0     ADULT BELOW 65
# 1     ADULT BELOW 65
# 2     ADULT BELOW 65
# 3     ADULT BELOW 65
# 4          ADULT 65+
# ...              ...
# 9013       ADULT 65+
# 9014       ADULT 65+
# 9015       ADULT 65+
# 9016       ADULT 65+
# 9017       ADULT 65+
#
# [9018 rows x 14 columns]
