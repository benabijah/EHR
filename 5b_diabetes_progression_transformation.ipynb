# %%
import pandas as pd
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Compare structure of raw data and transformed data

# %%
# read untransformed data
diabetes_cohort = pd.read_csv('/content/drive/MyDrive/Data/Output/diabetes_cohort.csv')
diabetes_cohort.head(7)
# Out:
#           BENE_ID   CCSR_CATEGORY_DESCRIPTION_updated    YR  \
# 0 -10000010288010                             Obesity  2015
# 1 -10000010288010  Socioeconomic or lifestyle factors  2015
# 2 -10000010288010                         Prediabetes  2015
# 3 -10000010287943            Heart disease or failure  2015
# 4 -10000010287943                             Obesity  2015
# 5 -10000010287943                         Prediabetes  2015
# 6 -10000010287943  Socioeconomic or lifestyle factors  2015
#
#    TIME_SINCE_ENROLLMT
# 0                    5
# 1                   10
# 2                   11
# 3                    2
# 4                    3
# 5                    6
# 6                    8

# %%
# read transformed data
diabetes_cohort_transformed = pd.read_csv('/content/drive/MyDrive/Data/Output/diab_cohort.csv')
diabetes_cohort_transformed
# Out:
#              BENE_ID  TIME  STATE  Obesity  \
# 0    -10000010288010     5      0        1
# 1    -10000010288010    10      0        1
# 2    -10000010288010    11      1        1
# 3    -10000010287943     2      0        0
# 4    -10000010287943     3      0        1
# ...              ...   ...    ...      ...
# 7192 -10000010254676    26      1        1
# 7193 -10000010254671     2      0        1
# 7194 -10000010254671     7      0        1
# 7195 -10000010254671     8      1        1
# 7196 -10000010254671     9      1        1
#
#       Socioeconomic.or.lifestyle.factors  Heart.disease.or.failure  \
# 0                                      0                         0
# 1                                      1                         0
# 2                                      1                         0
# 3                                      0                         1
# 4                                      0                         1
# ...                                  ...                       ...
# 7192                                   1                         0
# 7193                                   0                         0
# 7194                                   1                         0
# 7195                                   1                         0
# 7196                                   1                         1
#
#       Hypertension  Sleep.wake.disorders  Depressive.or.anxiety.disorders  \
# 0                0                     0                                0
# 1                0                     0                                0
# 2                0                     0                                0
# 3                0                     0                                0
# 4                0                     0                                0
# ...            ...                   ...                              ...
# 7192             1                     0                                0
# 7193             0                     0                                0
# 7194             0                     0                                0
# 7195             0                     0                                0
# 7196             0                     0                                0
#
#       Alcohol.related.disorders  SEX_IDENT_CD  BENE_RACE_CD  AGE_CALC  \
# 0                             0             1             5        54
# 1                             0             1             5        54
# 2                             0             1             5        54
# 3                             0             2             1        75
# 4                             0             2             1        75
# ...                         ...           ...           ...       ...
# 7192                          0             1             1        71
# 7193                          0             2             2        74
# 7194                          0             2             2        74
# 7195                          0             2             2        74
# 7196                          0             2             2        74
#
#              AGE_GRP
# 0     ADULT BELOW 65
# 1     ADULT BELOW 65
# 2     ADULT BELOW 65
# 3          ADULT 65+
# 4          ADULT 65+
# ...              ...
# 7192       ADULT 65+
# 7193       ADULT 65+
# 7194       ADULT 65+
# 7195       ADULT 65+
# 7196       ADULT 65+
#
# [7197 rows x 14 columns]
