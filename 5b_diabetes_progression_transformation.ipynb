# %%
import pandas as pd
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Compare structure of raw data and transformed data

# %%
# read untransformed data
diabetes_cohort = pd.read_csv('/content/drive/MyDrive/Data/Output/diabetes_cohort.csv')
diabetes_cohort.head(7)
# Out:
#           BENE_ID           CCSR_CATEGORY_DESCRIPTION    YR  MONTH  STATE  \
# 0 -10000010288010                             Obesity  2022      5      0
# 1 -10000010288010  Socioeconomic or lifestyle factors  2022     10      0
# 2 -10000010288010                         Prediabetes  2022     11      1
# 3 -10000010288009                        Hypertension  2022      2      0
# 4 -10000010288009            Heart disease or failure  2022      9      0
# 5 -10000010288009                             Obesity  2022      9      0
# 6 -10000010288009  Socioeconomic or lifestyle factors  2022      9      0
#
#    TIME_SINCE_PREDIAB
# 0                  -6
# 1                  -1
# 2                   0
# 3                  -9
# 4                  -2
# 5                  -2
# 6                  -2

# %%
# read transformed data
diabetes_cohort_transformed = pd.read_csv('/content/drive/MyDrive/Data/Output/diab_cohort.csv')
diabetes_cohort_transformed
# Out:
#              BENE_ID  STATE  TIME_SINCE_PREDIAB  Obesity  \
# 0    -10000010288010      1                   0        1
# 1    -10000010288009      1                   0        1
# 2    -10000010287992      1                   0        0
# 3    -10000010287992      2                   1        1
# 4    -10000010287992      2                   2        1
# ...              ...    ...                 ...      ...
# 8214 -10000010254672      1                   4        1
# 8215 -10000010254671      1                   0        0
# 8216 -10000010254671      1                   1        0
# 8217 -10000010254671      1                   2        1
# 8218 -10000010254671      1                   4        1
#
#       Socioeconomic or lifestyle factors  Hypertension  \
# 0                                      1             0
# 1                                      1             1
# 2                                      0             0
# ...
